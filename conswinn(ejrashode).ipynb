# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Data/Deepglobe.zip -d /content/dataset/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/train/723199_sat.jpg
#   inflating: /content/dataset/train/723226_mask.png
#   inflating: /content/dataset/train/723226_sat.jpg
#   inflating: /content/dataset/train/723436_mask.png
#   inflating: /content/dataset/train/723436_sat.jpg
#   inflating: /content/dataset/train/723483_mask.png
#   inflating: /content/dataset/train/723483_sat.jpg
#   inflating: /content/dataset/train/723622_mask.png
#   inflating: /content/dataset/train/723622_sat.jpg
#   inflating: /content/dataset/train/723722_mask.png
#   inflating: /content/dataset/train/723722_sat.jpg
#   inflating: /content/dataset/train/723970_mask.png
#   inflating: /content/dataset/train/723970_sat.jpg
#   inflating: /content/dataset/train/723990_mask.png
#   inflating: /content/dataset/train/723990_sat.jpg
#   inflating: /content/dataset/train/724095_mask.png
#   inflating: /content/dataset/train/724095_sat.jpg
#   inflating: /content/dataset/train/724431_mask.png
#   inflating: /content/dataset/train/724431_sat.jpg
#   inflating: /content/dataset/train/724485_mask.png
#   inflating: /content/dataset/train/724485_sat.jpg
#   inflating: /content/dataset/train/724705_mask.png
#   inflating: /content/dataset/train/724705_sat.jpg
#   inflating: /content/dataset/train/724870_mask.png
#   inflating: /content/dataset/train/724870_sat.jpg
#   inflating: /content/dataset/train/724941_mask.png
#   inflating: /content/dataset/train/724941_sat.jpg
#   inflating: /content/dataset/train/724993_mask.png
#   inflating: /content/dataset/train/724993_sat.jpg
#   inflating: /content/dataset/train/725014_mask.png
#   inflating: /content/dataset/train/725014_sat.jpg
#   inflating: /content/dataset/train/725115_mask.png
#   inflating: /content/dataset/train/725115_sat.jpg
#   inflating: /content/dataset/train/725183_mask.png
#   inflating: /content/dataset/train/725183_sat.jpg
#   inflating: /content/dataset/train/725239_mask.png
#   inflating: /content/dataset/train/725239_sat.jpg
#   inflating: /content/dataset/train/725249_mask.png
#   inflating: /content/dataset/train/725249_sat.jpg
#   inflating: /content/dataset/train/725359_mask.png
#   inflating: /content/dataset/train/725359_sat.jpg
#   inflating: /content/dataset/train/725392_mask.png
#   inflating: /content/dataset/train/725392_sat.jpg
#   inflating: /content/dataset/train/725472_mask.png
#   inflating: /content/dataset/train/725472_sat.jpg
#   inflating: /content/dataset/train/725747_mask.png
#   inflating: /content/dataset/train/725747_sat.jpg
#   inflating: /content/dataset/train/725833_mask.png
#   inflating: /content/dataset/train/725833_sat.jpg
#   inflating: /content/dataset/train/725843_mask.png
#   inflating: /content/dataset/train/725843_sat.jpg
#   inflating: /content/dataset/train/726148_mask.png
#   inflating: /content/dataset/train/726148_sat.jpg
#   inflating: /content/dataset/train/726271_mask.png
#   inflating: /content/dataset/train/726271_sat.jpg
#   inflating: /content/dataset/train/726557_mask.png
#   inflating: /content/dataset/train/726557_sat.jpg
#   inflating: /content/dataset/train/726668_mask.png
#   inflating: /content/dataset/train/726668_sat.jpg
#   inflating: /content/dataset/train/72689_mask.png
#   inflating: /content/dataset/train/72689_sat.jpg
#   inflating: /content/dataset/train/727230_mask.png
#   inflating: /content/dataset/train/727230_sat.jpg
#   inflating: /content/dataset/train/727315_mask.png
#   inflating: /content/dataset/train/727315_sat.jpg
#   inflating: /content/dataset/train/727435_mask.png
#   inflating: /content/dataset/train/727435_sat.jpg
#   inflating: /content/dataset/train/727513_mask.png
#   inflating: /content/dataset/train/727513_sat.jpg
#   inflating: /content/dataset/train/727773_mask.png
#   inflating: /content/dataset/train/727773_sat.jpg
#   inflating: /content/dataset/train/727840_mask.png
#   inflating: /content/dataset/train/727840_sat.jpg
#   inflating: /content/dataset/train/728547_mask.png
#   inflating: /content/dataset/train/728547_sat.jpg
#   inflating: /content/dataset/train/728843_mask.png
#   inflating: /content/dataset/train/728843_sat.jpg
#   inflating: /content/dataset/train/729020_mask.png
#   inflating: /content/dataset/train/729020_sat.jpg
#   inflating: /content/dataset/train/729246_mask.png
#   inflating: /content/dataset/train/729246_sat.jpg
#   inflating: /content/dataset/train/729444_mask.png
#   inflating: /content/dataset/train/729444_sat.jpg
#   inflating: /content/dataset/train/729661_mask.png
#   inflating: /content/dataset/train/729661_sat.jpg
#   inflating: /content/dataset/train/729885_mask.png
#   inflating: /content/dataset/train/729885_sat.jpg
#   inflating: /content/dataset/train/730185_mask.png
#   inflating: /content/dataset/train/730185_sat.jpg
#   inflating: /content/dataset/train/730270_mask.png
#   inflating: /content/dataset/train/730270_sat.jpg
#   inflating: /content/dataset/train/730281_mask.png
#   inflating: /content/dataset/train/730281_sat.jpg
#   inflating: /content/dataset/train/73033_mask.png
#   inflating: /content/dataset/train/73033_sat.jpg
#   inflating: /content/dataset/train/730376_mask.png
#   inflating: /content/dataset/train/730376_sat.jpg
#   inflating: /content/dataset/train/730524_mask.png
#   inflating: /content/dataset/train/730524_sat.jpg
#   inflating: /content/dataset/train/730531_mask.png
#   inflating: /content/dataset/train/730531_sat.jpg
#   inflating: /content/dataset/train/730614_mask.png
#   inflating: /content/dataset/train/730614_sat.jpg
#   inflating: /content/dataset/train/730763_mask.png
#   inflating: /content/dataset/train/730763_sat.jpg
#   inflating: /content/dataset/train/730949_mask.png
#   inflating: /content/dataset/train/730949_sat.jpg
#   inflating: /content/dataset/train/730973_mask.png
#   inflating: /content/dataset/train/730973_sat.jpg
#   inflating: /content/dataset/train/731150_mask.png
#   inflating: /content/dataset/train/731150_sat.jpg
#   inflating: /content/dataset/train/731187_mask.png
#   inflating: /content/dataset/train/731187_sat.jpg
#   inflating: /content/dataset/train/731391_mask.png
#   inflating: /content/dataset/train/731391_sat.jpg
#   inflating: /content/dataset/train/731685_mask.png
#   inflating: /content/dataset/train/731685_sat.jpg
#   inflating: /content/dataset/train/73183_mask.png
#   inflating: /content/dataset/train/73183_sat.jpg
#   inflating: /content/dataset/train/731856_mask.png
#   inflating: /content/dataset/train/731856_sat.jpg
#   inflating: /content/dataset/train/73185_mask.png
#   inflating: /content/dataset/train/73185_sat.jpg
#   inflating: /content/dataset/train/732011_mask.png
#   inflating: /content/dataset/train/732011_sat.jpg
#   inflating: /content/dataset/train/732079_mask.png
#   inflating: /content/dataset/train/732079_sat.jpg
#   inflating: /content/dataset/train/732273_mask.png
#   inflating: /content/dataset/train/732273_sat.jpg
#   inflating: /content/dataset/train/732310_mask.png
#   inflating: /content/dataset/train/732310_sat.jpg
#   inflating: /content/dataset/train/732602_mask.png
#   inflating: /content/dataset/train/732602_sat.jpg
#   inflating: /content/dataset/train/732691_mask.png
#   inflating: /content/dataset/train/732691_sat.jpg
#   inflating: /content/dataset/train/732841_mask.png
#   inflating: /content/dataset/train/732841_sat.jpg
#   inflating: /content/dataset/train/733019_mask.png
#   inflating: /content/dataset/train/733019_sat.jpg
#   inflating: /content/dataset/train/733110_mask.png
#   inflating: /content/dataset/train/733110_sat.jpg
#   inflating: /content/dataset/train/733133_mask.png
#   inflating: /content/dataset/train/733133_sat.jpg
#   inflating: /content/dataset/train/733417_mask.png
#   inflating: /content/dataset/train/733417_sat.jpg
#   inflating: /content/dataset/train/733437_mask.png
#   inflating: /content/dataset/train/733437_sat.jpg
#   inflating: /content/dataset/train/733755_mask.png
#   inflating: /content/dataset/train/733755_sat.jpg
#   inflating: /content/dataset/train/733881_mask.png
#   inflating: /content/dataset/train/733881_sat.jpg
#   inflating: /content/dataset/train/733966_mask.png
#   inflating: /content/dataset/train/733966_sat.jpg
#   inflating: /content/dataset/train/734040_mask.png
#   inflating: /content/dataset/train/734040_sat.jpg
#   inflating: /content/dataset/train/734244_mask.png
#   inflating: /content/dataset/train/734244_sat.jpg
#   inflating: /content/dataset/train/734534_mask.png
#   inflating: /content/dataset/train/734534_sat.jpg
#   inflating: /content/dataset/train/734610_mask.png
#   inflating: /content/dataset/train/734610_sat.jpg
#   inflating: /content/dataset/train/734621_mask.png
#   inflating: /content/dataset/train/734621_sat.jpg
#   inflating: /content/dataset/train/734675_mask.png
#   inflating: /content/dataset/train/734675_sat.jpg
#   inflating: /content/dataset/train/734704_mask.png
#   inflating: /content/dataset/train/734704_sat.jpg
#   inflating: /content/dataset/train/734903_mask.png
#   inflating: /content/dataset/train/734903_sat.jpg
#   inflating: /content/dataset/train/735003_mask.png
#   inflating: /content/dataset/train/735003_sat.jpg
#   inflating: /content/dataset/train/735075_mask.png
#   inflating: /content/dataset/train/735075_sat.jpg
#   inflating: /content/dataset/train/735376_mask.png
#   inflating: /content/dataset/train/735376_sat.jpg
#   inflating: /content/dataset/train/735617_mask.png
#   inflating: /content/dataset/train/735617_sat.jpg
#   inflating: /content/dataset/train/735784_mask.png
#   inflating: /content/dataset/train/735784_sat.jpg
#   inflating: /content/dataset/train/735929_mask.png
#   inflating: /content/dataset/train/735929_sat.jpg
#   inflating: /content/dataset/train/735969_mask.png
#   inflating: /content/dataset/train/735969_sat.jpg
#   inflating: /content/dataset/train/736091_mask.png
#   inflating: /content/dataset/train/736091_sat.jpg
#   inflating: /content/dataset/train/736329_mask.png
#   inflating: /content/dataset/train/736329_sat.jpg
#   inflating: /content/dataset/train/736444_mask.png
#   inflating: /content/dataset/train/736444_sat.jpg
#   inflating: /content/dataset/train/736465_mask.png
#   inflating: /content/dataset/train/736465_sat.jpg
#   inflating: /content/dataset/train/736629_mask.png
#   inflating: /content/dataset/train/736629_sat.jpg
#   inflating: /content/dataset/train/736666_mask.png
#   inflating: /content/dataset/train/736666_sat.jpg
#   inflating: /content/dataset/train/736732_mask.png
#   inflating: /content/dataset/train/736732_sat.jpg
#   inflating: /content/dataset/train/736761_mask.png
#   inflating: /content/dataset/train/736761_sat.jpg
#   inflating: /content/dataset/train/737263_mask.png
#   inflating: /content/dataset/train/737263_sat.jpg
#   inflating: /content/dataset/train/7372_mask.png
#   inflating: /content/dataset/train/7372_sat.jpg
#   inflating: /content/dataset/train/737508_mask.png
#   inflating: /content/dataset/train/737508_sat.jpg
#   inflating: /content/dataset/train/737584_mask.png
#   inflating: /content/dataset/train/737584_sat.jpg
#   inflating: /content/dataset/train/737666_mask.png
#   inflating: /content/dataset/train/737666_sat.jpg
#   inflating: /content/dataset/train/738170_mask.png
#   inflating: /content/dataset/train/738170_sat.jpg
#   inflating: /content/dataset/train/738407_mask.png
#   inflating: /content/dataset/train/738407_sat.jpg
#   inflating: /content/dataset/train/738456_mask.png
#   inflating: /content/dataset/train/738456_sat.jpg
#   inflating: /content/dataset/train/73857_mask.png
#   inflating: /content/dataset/train/73857_sat.jpg
#   inflating: /content/dataset/train/73867_mask.png
#   inflating: /content/dataset/train/73867_sat.jpg
#   inflating: /content/dataset/train/738721_mask.png
#   inflating: /content/dataset/train/738721_sat.jpg
#   inflating: /content/dataset/train/738813_mask.png
#   inflating: /content/dataset/train/738813_sat.jpg
#   inflating: /content/dataset/train/738906_mask.png
#   inflating: /content/dataset/train/738906_sat.jpg
#   inflating: /content/dataset/train/739225_mask.png
#   inflating: /content/dataset/train/739225_sat.jpg
#   inflating: /content/dataset/train/739465_mask.png
#   inflating: /content/dataset/train/739465_sat.jpg
#   inflating: /content/dataset/train/73959_mask.png
#   inflating: /content/dataset/train/73959_sat.jpg
#   inflating: /content/dataset/train/739815_mask.png
#   inflating: /content/dataset/train/739815_sat.jpg
#   inflating: /content/dataset/train/74010_mask.png
#   inflating: /content/dataset/train/74010_sat.jpg
#   inflating: /content/dataset/train/740261_mask.png
#   inflating: /content/dataset/train/740261_sat.jpg
#   inflating: /content/dataset/train/74057_mask.png
#   inflating: /content/dataset/train/74057_sat.jpg
#   inflating: /content/dataset/train/740865_mask.png
#   inflating: /content/dataset/train/740865_sat.jpg
#   inflating: /content/dataset/train/741188_mask.png
#   inflating: /content/dataset/train/741188_sat.jpg
#   inflating: /content/dataset/train/74143_mask.png
#   inflating: /content/dataset/train/74143_sat.jpg
#   inflating: /content/dataset/train/741476_mask.png
#   inflating: /content/dataset/train/741476_sat.jpg
#   inflating: /content/dataset/train/741508_mask.png
#   inflating: /content/dataset/train/741508_sat.jpg
#   inflating: /content/dataset/train/741728_mask.png
#   inflating: /content/dataset/train/741728_sat.jpg
#   inflating: /content/dataset/train/741749_mask.png
#   inflating: /content/dataset/train/741749_sat.jpg
#   inflating: /content/dataset/train/742031_mask.png
#   inflating: /content/dataset/train/742031_sat.jpg
#   inflating: /content/dataset/train/742141_mask.png
#   inflating: /content/dataset/train/742141_sat.jpg
#   inflating: /content/dataset/train/742390_mask.png
#   inflating: /content/dataset/train/742390_sat.jpg
#   inflating: /content/dataset/train/742461_mask.png
#   inflating: /content/dataset/train/742461_sat.jpg
#   inflating: /content/dataset/train/742678_mask.png
#   inflating: /content/dataset/train/742678_sat.jpg
#   inflating: /content/dataset/train/742880_mask.png
#   inflating: /content/dataset/train/742880_sat.jpg
#   inflating: /content/dataset/train/743007_mask.png
#   inflating: /content/dataset/train/743007_sat.jpg
#   inflating: /content/dataset/train/743078_mask.png
#   inflating: /content/dataset/train/743078_sat.jpg
#   inflating: /content/dataset/train/743232_mask.png
#   inflating: /content/dataset/train/743232_sat.jpg
#   inflating: /content/dataset/train/743450_mask.png
#   inflating: /content/dataset/train/743450_sat.jpg
#   inflating: /content/dataset/train/743506_mask.png
#   inflating: /content/dataset/train/743506_sat.jpg
#   inflating: /content/dataset/train/743617_mask.png
#   inflating: /content/dataset/train/743617_sat.jpg
#   inflating: /content/dataset/train/743645_mask.png
#   inflating: /content/dataset/train/743645_sat.jpg
#   inflating: /content/dataset/train/744056_mask.png
#   inflating: /content/dataset/train/744056_sat.jpg
#   inflating: /content/dataset/train/744091_mask.png
#   inflating: /content/dataset/train/744091_sat.jpg
#   inflating: /content/dataset/train/744092_mask.png
#   inflating: /content/dataset/train/744092_sat.jpg
#   inflating: /content/dataset/train/744129_mask.png
#   inflating: /content/dataset/train/744129_sat.jpg
#   inflating: /content/dataset/train/744188_mask.png
#   inflating: /content/dataset/train/744188_sat.jpg
#   inflating: /content/dataset/train/744794_mask.png
#   inflating: /content/dataset/train/744794_sat.jpg
#   inflating: /content/dataset/train/744973_mask.png
#   inflating: /content/dataset/train/744973_sat.jpg
#   inflating: /content/dataset/train/744975_mask.png
#   inflating: /content/dataset/train/744975_sat.jpg
#   inflating: /content/dataset/train/74497_mask.png
#   inflating: /content/dataset/train/74497_sat.jpg
#   inflating: /content/dataset/train/745086_mask.png
#   inflating: /content/dataset/train/745086_sat.jpg
#   inflating: /content/dataset/train/745107_mask.png
#   inflating: /content/dataset/train/745107_sat.jpg
#   inflating: /content/dataset/train/745266_mask.png
#   inflating: /content/dataset/train/745266_sat.jpg
#   inflating: /content/dataset/train/74552_mask.png
#   inflating: /content/dataset/train/74552_sat.jpg
#   inflating: /content/dataset/train/745704_mask.png
#   inflating: /content/dataset/train/745704_sat.jpg
#   inflating: /content/dataset/train/745880_mask.png
#   inflating: /content/dataset/train/745880_sat.jpg
#   inflating: /content/dataset/train/745902_mask.png
#   inflating: /content/dataset/train/745902_sat.jpg
#   inflating: /content/dataset/train/746005_mask.png
#   inflating: /content/dataset/train/746005_sat.jpg
#   inflating: /content/dataset/train/74600_mask.png
#   inflating: /content/dataset/train/74600_sat.jpg
#   inflating: /content/dataset/train/746094_mask.png
#   inflating: /content/dataset/train/746094_sat.jpg
#   inflating: /content/dataset/train/746431_mask.png
#   inflating: /content/dataset/train/746431_sat.jpg
#   inflating: /content/dataset/train/746499_mask.png
#   inflating: /content/dataset/train/746499_sat.jpg
#   inflating: /content/dataset/train/746743_mask.png
#   inflating: /content/dataset/train/746743_sat.jpg
#   inflating: /content/dataset/train/746839_mask.png
#   inflating: /content/dataset/train/746839_sat.jpg
#   inflating: /content/dataset/train/747312_mask.png
#   inflating: /content/dataset/train/747312_sat.jpg
#   inflating: /content/dataset/train/74737_mask.png
#   inflating: /content/dataset/train/74737_sat.jpg
#   inflating: /content/dataset/train/747392_mask.png
#   inflating: /content/dataset/train/747392_sat.jpg
#   inflating: /content/dataset/train/747616_mask.png
#   inflating: /content/dataset/train/747616_sat.jpg
#   inflating: /content/dataset/train/748045_mask.png
#   inflating: /content/dataset/train/748045_sat.jpg
#   inflating: /content/dataset/train/748093_mask.png
#   inflating: /content/dataset/train/748093_sat.jpg
#   inflating: /content/dataset/train/748425_mask.png
#   inflating: /content/dataset/train/748425_sat.jpg
#   inflating: /content/dataset/train/748548_mask.png
#   inflating: /content/dataset/train/748548_sat.jpg
#   inflating: /content/dataset/train/748601_mask.png
#   inflating: /content/dataset/train/748601_sat.jpg
#   inflating: /content/dataset/train/748913_mask.png
#   inflating: /content/dataset/train/748913_sat.jpg
#   inflating: /content/dataset/train/748989_mask.png
#   inflating: /content/dataset/train/748989_sat.jpg
#   inflating: /content/dataset/train/749627_mask.png
#   inflating: /content/dataset/train/749627_sat.jpg
#   inflating: /content/dataset/train/749641_mask.png
#   inflating: /content/dataset/train/749641_sat.jpg
#   inflating: /content/dataset/train/749648_mask.png
#   inflating: /content/dataset/train/749648_sat.jpg
#   inflating: /content/dataset/train/749787_mask.png
#   inflating: /content/dataset/train/749787_sat.jpg
#   inflating: /content/dataset/train/749859_mask.png
#   inflating: /content/dataset/train/749859_sat.jpg
#   inflating: /content/dataset/train/74988_mask.png
#   inflating: /content/dataset/train/74988_sat.jpg
#   inflating: /content/dataset/train/74989_mask.png
#   inflating: /content/dataset/train/74989_sat.jpg
#   inflating: /content/dataset/train/750187_mask.png
#   inflating: /content/dataset/train/750187_sat.jpg
#   inflating: /content/dataset/train/750210_mask.png
#   inflating: /content/dataset/train/750210_sat.jpg
#   inflating: /content/dataset/train/750445_mask.png
#   inflating: /content/dataset/train/750445_sat.jpg
#   inflating: /content/dataset/train/750485_mask.png
#   inflating: /content/dataset/train/750485_sat.jpg
#   inflating: /content/dataset/train/750530_mask.png
#   inflating: /content/dataset/train/750530_sat.jpg
#   inflating: /content/dataset/train/750608_mask.png
#   inflating: /content/dataset/train/750608_sat.jpg
#   inflating: /content/dataset/train/750772_mask.png
#   inflating: /content/dataset/train/750772_sat.jpg
#   inflating: /content/dataset/train/750897_mask.png
#   inflating: /content/dataset/train/750897_sat.jpg
#   inflating: /content/dataset/train/750956_mask.png
#   inflating: /content/dataset/train/750956_sat.jpg
#   inflating: /content/dataset/train/751202_mask.png
#   inflating: /content/dataset/train/751202_sat.jpg
#   inflating: /content/dataset/train/751448_mask.png
#   inflating: /content/dataset/train/751448_sat.jpg
#   inflating: /content/dataset/train/751585_mask.png
#   inflating: /content/dataset/train/751585_sat.jpg
#   inflating: /content/dataset/train/751700_mask.png
#   inflating: /content/dataset/train/751700_sat.jpg
#   inflating: /content/dataset/train/752005_mask.png
#   inflating: /content/dataset/train/752005_sat.jpg
#   inflating: /content/dataset/train/752517_mask.png
#   inflating: /content/dataset/train/752517_sat.jpg
#   inflating: /content/dataset/train/752601_mask.png
#   inflating: /content/dataset/train/752601_sat.jpg
#   inflating: /content/dataset/train/752614_mask.png
#   inflating: /content/dataset/train/752614_sat.jpg
#   inflating: /content/dataset/train/752708_mask.png
#   inflating: /content/dataset/train/752708_sat.jpg
#   inflating: /content/dataset/train/753016_mask.png
#   inflating: /content/dataset/train/753016_sat.jpg
#   inflating: /content/dataset/train/753215_mask.png
#   inflating: /content/dataset/train/753215_sat.jpg
#   inflating: /content/dataset/train/75330_mask.png
#   inflating: /content/dataset/train/75330_sat.jpg
#   inflating: /content/dataset/train/753384_mask.png
#   inflating: /content/dataset/train/753384_sat.jpg
#   inflating: /content/dataset/train/753390_mask.png
#   inflating: /content/dataset/train/753390_sat.jpg
#   inflating: /content/dataset/train/753614_mask.png
#   inflating: /content/dataset/train/753614_sat.jpg
#   inflating: /content/dataset/train/753638_mask.png
#   inflating: /content/dataset/train/753638_sat.jpg
#   inflating: /content/dataset/train/753663_mask.png
#   inflating: /content/dataset/train/753663_sat.jpg
#   inflating: /content/dataset/train/753676_mask.png
#   inflating: /content/dataset/train/753676_sat.jpg
#   inflating: /content/dataset/train/753694_mask.png
#   inflating: /content/dataset/train/753694_sat.jpg
#   inflating: /content/dataset/train/753907_mask.png
#   inflating: /content/dataset/train/753907_sat.jpg
#   inflating: /content/dataset/train/754467_mask.png
#   inflating: /content/dataset/train/754467_sat.jpg
#   inflating: /content/dataset/train/754506_mask.png
#   inflating: /content/dataset/train/754506_sat.jpg
#   inflating: /content/dataset/train/754539_mask.png
#   inflating: /content/dataset/train/754539_sat.jpg
#   inflating: /content/dataset/train/754670_mask.png
#   inflating: /content/dataset/train/754670_sat.jpg
#   inflating: /content/dataset/train/754944_mask.png
#   inflating: /content/dataset/train/754944_sat.jpg
#   inflating: /content/dataset/train/754948_mask.png
#   inflating: /content/dataset/train/754948_sat.jpg
#   inflating: /content/dataset/train/755069_mask.png
#   inflating: /content/dataset/train/755069_sat.jpg
#   inflating: /content/dataset/train/755342_mask.png
#   inflating: /content/dataset/train/755342_sat.jpg
#   inflating: /content/dataset/train/755362_mask.png
#   inflating: /content/dataset/train/755362_sat.jpg
#   inflating: /content/dataset/train/755575_mask.png
#   inflating: /content/dataset/train/755575_sat.jpg
#   inflating: /content/dataset/train/755605_mask.png
#   inflating: /content/dataset/train/755605_sat.jpg
#   inflating: /content/dataset/train/75561_mask.png
#   inflating: /content/dataset/train/75561_sat.jpg
#   inflating: /content/dataset/train/755736_mask.png
#   inflating: /content/dataset/train/755736_sat.jpg
#   inflating: /content/dataset/train/755954_mask.png
#   inflating: /content/dataset/train/755954_sat.jpg
#   inflating: /content/dataset/train/755970_mask.png
#   inflating: /content/dataset/train/755970_sat.jpg
#   inflating: /content/dataset/train/756116_mask.png
#   inflating: /content/dataset/train/756116_sat.jpg
#   inflating: /content/dataset/train/75611_mask.png
#   inflating: /content/dataset/train/75611_sat.jpg
#   inflating: /content/dataset/train/756844_mask.png
#   inflating: /content/dataset/train/756844_sat.jpg
#   inflating: /content/dataset/train/757028_mask.png
#   inflating: /content/dataset/train/757028_sat.jpg
#   inflating: /content/dataset/train/757146_mask.png
#   inflating: /content/dataset/train/757146_sat.jpg
#   inflating: /content/dataset/train/757279_mask.png
#   inflating: /content/dataset/train/757279_sat.jpg
#   inflating: /content/dataset/train/757333_mask.png
#   inflating: /content/dataset/train/757333_sat.jpg
#   inflating: /content/dataset/train/757498_mask.png
#   inflating: /content/dataset/train/757498_sat.jpg
#   inflating: /content/dataset/train/757554_mask.png
#   inflating: /content/dataset/train/757554_sat.jpg
#   inflating: /content/dataset/train/757803_mask.png
#   inflating: /content/dataset/train/757803_sat.jpg
#   inflating: /content/dataset/train/757829_mask.png
#   inflating: /content/dataset/train/757829_sat.jpg
#   inflating: /content/dataset/train/757855_mask.png
#   inflating: /content/dataset/train/757855_sat.jpg
#   inflating: /content/dataset/train/757922_mask.png
#   inflating: /content/dataset/train/757922_sat.jpg
#   inflating: /content/dataset/train/75815_mask.png
#   inflating: /content/dataset/train/75815_sat.jpg
#   inflating: /content/dataset/train/758229_mask.png
#   inflating: /content/dataset/train/758229_sat.jpg
#   inflating: /content/dataset/train/758267_mask.png
#   inflating: /content/dataset/train/758267_sat.jpg
#   inflating: /content/dataset/train/758397_mask.png
#   inflating: /content/dataset/train/758397_sat.jpg
#   inflating: /content/dataset/train/758481_mask.png
#   inflating: /content/dataset/train/758481_sat.jpg
#   inflating: /content/dataset/train/758578_mask.png
#   inflating: /content/dataset/train/758578_sat.jpg
#   inflating: /content/dataset/train/758682_mask.png
#   inflating: /content/dataset/train/758682_sat.jpg
#   inflating: /content/dataset/train/758734_mask.png
#   inflating: /content/dataset/train/758734_sat.jpg
#   inflating: /content/dataset/train/758779_mask.png
#   inflating: /content/dataset/train/758779_sat.jpg
#   inflating: /content/dataset/train/758828_mask.png
#   inflating: /content/dataset/train/758828_sat.jpg
#   inflating: /content/dataset/train/758957_mask.png
#   inflating: /content/dataset/train/758957_sat.jpg
#   inflating: /content/dataset/train/758973_mask.png
#   inflating: /content/dataset/train/758973_sat.jpg
#   inflating: /content/dataset/train/759019_mask.png
#   inflating: /content/dataset/train/759019_sat.jpg
#   inflating: /content/dataset/train/759091_mask.png
#   inflating: /content/dataset/train/759091_sat.jpg
#   inflating: /content/dataset/train/759166_mask.png
#   inflating: /content/dataset/train/759166_sat.jpg
#   inflating: /content/dataset/train/759355_mask.png
#   inflating: /content/dataset/train/759355_sat.jpg
#   inflating: /content/dataset/train/759445_mask.png
#   inflating: /content/dataset/train/759445_sat.jpg
#   inflating: /content/dataset/train/759537_mask.png
#   inflating: /content/dataset/train/759537_sat.jpg
#   inflating: /content/dataset/train/759607_mask.png
#   inflating: /content/dataset/train/759607_sat.jpg
#   inflating: /content/dataset/train/759655_mask.png
#   inflating: /content/dataset/train/759655_sat.jpg
#   inflating: /content/dataset/train/759945_mask.png
#   inflating: /content/dataset/train/759945_sat.jpg
#   inflating: /content/dataset/train/759949_mask.png
#   inflating: /content/dataset/train/759949_sat.jpg
#   inflating: /content/dataset/train/760036_mask.png
#   inflating: /content/dataset/train/760036_sat.jpg
#   inflating: /content/dataset/train/760069_mask.png
#   inflating: /content/dataset/train/760069_sat.jpg
#   inflating: /content/dataset/train/760170_mask.png
#   inflating: /content/dataset/train/760170_sat.jpg
#   inflating: /content/dataset/train/760255_mask.png
#   inflating: /content/dataset/train/760255_sat.jpg
#   inflating: /content/dataset/train/760294_mask.png
#   inflating: /content/dataset/train/760294_sat.jpg
#   inflating: /content/dataset/train/760338_mask.png
#   inflating: /content/dataset/train/760338_sat.jpg
#   inflating: /content/dataset/train/760377_mask.png
#   inflating: /content/dataset/train/760377_sat.jpg
#   inflating: /content/dataset/train/760436_mask.png
#   inflating: /content/dataset/train/760436_sat.jpg
#   inflating: /content/dataset/train/760891_mask.png
#   inflating: /content/dataset/train/760891_sat.jpg
#   inflating: /content/dataset/train/760962_mask.png
#   inflating: /content/dataset/train/760962_sat.jpg
#   inflating: /content/dataset/train/761056_mask.png
#   inflating: /content/dataset/train/761056_sat.jpg
#   inflating: /content/dataset/train/761119_mask.png
#   inflating: /content/dataset/train/761119_sat.jpg
#   inflating: /content/dataset/train/761239_mask.png
#   inflating: /content/dataset/train/761239_sat.jpg
#   inflating: /content/dataset/train/761646_mask.png
#   inflating: /content/dataset/train/761646_sat.jpg
#   inflating: /content/dataset/train/761666_mask.png
#   inflating: /content/dataset/train/761666_sat.jpg
#   inflating: /content/dataset/train/761866_mask.png
#   inflating: /content/dataset/train/761866_sat.jpg
#   inflating: /content/dataset/train/762023_mask.png
#   inflating: /content/dataset/train/762023_sat.jpg
#   inflating: /content/dataset/train/762116_mask.png
#   inflating: /content/dataset/train/762116_sat.jpg
#   inflating: /content/dataset/train/762387_mask.png
#   inflating: /content/dataset/train/762387_sat.jpg
#   inflating: /content/dataset/train/763393_mask.png
#   inflating: /content/dataset/train/763393_sat.jpg
#   inflating: /content/dataset/train/763554_mask.png
#   inflating: /content/dataset/train/763554_sat.jpg
#   inflating: /content/dataset/train/763876_mask.png
#   inflating: /content/dataset/train/763876_sat.jpg
#   inflating: /content/dataset/train/763947_mask.png
#   inflating: /content/dataset/train/763947_sat.jpg
#   inflating: /content/dataset/train/763964_mask.png
#   inflating: /content/dataset/train/763964_sat.jpg
#   inflating: /content/dataset/train/764015_mask.png
#   inflating: /content/dataset/train/764015_sat.jpg
#   inflating: /content/dataset/train/764194_mask.png
#   inflating: /content/dataset/train/764194_sat.jpg
#   inflating: /content/dataset/train/764272_mask.png
#   inflating: /content/dataset/train/764272_sat.jpg
#   inflating: /content/dataset/train/764386_mask.png
#   inflating: /content/dataset/train/764386_sat.jpg
#   inflating: /content/dataset/train/764396_mask.png
#   inflating: /content/dataset/train/764396_sat.jpg
#   inflating: /content/dataset/train/764473_mask.png
#   inflating: /content/dataset/train/764473_sat.jpg
#   inflating: /content/dataset/train/764483_mask.png
#   inflating: /content/dataset/train/764483_sat.jpg
#   inflating: /content/dataset/train/764632_mask.png
#   inflating: /content/dataset/train/764632_sat.jpg
#   inflating: /content/dataset/train/764954_mask.png
#   inflating: /content/dataset/train/764954_sat.jpg
#   inflating: /content/dataset/train/765293_mask.png
#   inflating: /content/dataset/train/765293_sat.jpg
#   inflating: /content/dataset/train/765415_mask.png
#   inflating: /content/dataset/train/765415_sat.jpg
#   inflating: /content/dataset/train/765458_mask.png
#   inflating: /content/dataset/train/765458_sat.jpg
#   inflating: /content/dataset/train/765569_mask.png
#   inflating: /content/dataset/train/765569_sat.jpg
#   inflating: /content/dataset/train/765839_mask.png
#   inflating: /content/dataset/train/765839_sat.jpg
#   inflating: /content/dataset/train/766110_mask.png
#   inflating: /content/dataset/train/766110_sat.jpg
#   inflating: /content/dataset/train/766187_mask.png
#   inflating: /content/dataset/train/766187_sat.jpg
#   inflating: /content/dataset/train/766257_mask.png
#   inflating: /content/dataset/train/766257_sat.jpg
#   inflating: /content/dataset/train/766536_mask.png
#   inflating: /content/dataset/train/766536_sat.jpg
#   inflating: /content/dataset/train/766872_mask.png
#   inflating: /content/dataset/train/766872_sat.jpg
#   inflating: /content/dataset/train/766889_mask.png
#   inflating: /content/dataset/train/766889_sat.jpg
#   inflating: /content/dataset/train/767144_mask.png
#   inflating: /content/dataset/train/767144_sat.jpg
#   inflating: /content/dataset/train/767261_mask.png
#   inflating: /content/dataset/train/767261_sat.jpg
#   inflating: /content/dataset/train/76736_mask.png
#   inflating: /content/dataset/train/76736_sat.jpg
#   inflating: /content/dataset/train/767432_mask.png
#   inflating: /content/dataset/train/767432_sat.jpg
#   inflating: /content/dataset/train/767454_mask.png
#   inflating: /content/dataset/train/767454_sat.jpg
#   inflating: /content/dataset/train/767496_mask.png
#   inflating: /content/dataset/train/767496_sat.jpg
#   inflating: /content/dataset/train/767537_mask.png
#   inflating: /content/dataset/train/767537_sat.jpg
#   inflating: /content/dataset/train/767677_mask.png
#   inflating: /content/dataset/train/767677_sat.jpg
#   inflating: /content/dataset/train/767726_mask.png
#   inflating: /content/dataset/train/767726_sat.jpg
#   inflating: /content/dataset/train/767812_mask.png
#   inflating: /content/dataset/train/767812_sat.jpg
#   inflating: /content/dataset/train/767819_mask.png
#   inflating: /content/dataset/train/767819_sat.jpg
#   inflating: /content/dataset/train/768007_mask.png
#   inflating: /content/dataset/train/768007_sat.jpg
#   inflating: /content/dataset/train/768045_mask.png
#   inflating: /content/dataset/train/768045_sat.jpg
#   inflating: /content/dataset/train/768086_mask.png
#   inflating: /content/dataset/train/768086_sat.jpg
#   inflating: /content/dataset/train/768224_mask.png
#   inflating: /content/dataset/train/768224_sat.jpg
#   inflating: /content/dataset/train/768401_mask.png
#   inflating: /content/dataset/train/768401_sat.jpg
#   inflating: /content/dataset/train/768818_mask.png
#   inflating: /content/dataset/train/768818_sat.jpg
#   inflating: /content/dataset/train/769104_mask.png
#   inflating: /content/dataset/train/769104_sat.jpg
#   inflating: /content/dataset/train/769154_mask.png
#   inflating: /content/dataset/train/769154_sat.jpg
#   inflating: /content/dataset/train/769287_mask.png
#   inflating: /content/dataset/train/769287_sat.jpg
#   inflating: /content/dataset/train/769360_mask.png
#   inflating: /content/dataset/train/769360_sat.jpg
#   inflating: /content/dataset/train/769376_mask.png
#   inflating: /content/dataset/train/769376_sat.jpg
#   inflating: /content/dataset/train/769666_mask.png
#   inflating: /content/dataset/train/769666_sat.jpg
#   inflating: /content/dataset/train/769777_mask.png
#   inflating: /content/dataset/train/769777_sat.jpg
#   inflating: /content/dataset/train/769782_mask.png
#   inflating: /content/dataset/train/769782_sat.jpg
#   inflating: /content/dataset/train/769940_mask.png
#   inflating: /content/dataset/train/769940_sat.jpg
#   inflating: /content/dataset/train/769960_mask.png
#   inflating: /content/dataset/train/769960_sat.jpg
#   inflating: /content/dataset/train/770001_mask.png
#   inflating: /content/dataset/train/770001_sat.jpg
#   inflating: /content/dataset/train/770292_mask.png
#   inflating: /content/dataset/train/770292_sat.jpg
#   inflating: /content/dataset/train/770434_mask.png
#   inflating: /content/dataset/train/770434_sat.jpg
#   inflating: /content/dataset/train/770503_mask.png
#   inflating: /content/dataset/train/770503_sat.jpg
#   inflating: /content/dataset/train/770634_mask.png
#   inflating: /content/dataset/train/770634_sat.jpg
#   inflating: /content/dataset/train/770659_mask.png
#   inflating: /content/dataset/train/770659_sat.jpg
#   inflating: /content/dataset/train/770696_mask.png
#   inflating: /content/dataset/train/770696_sat.jpg
#   inflating: /content/dataset/train/77085_mask.png
#   inflating: /content/dataset/train/77085_sat.jpg
#   inflating: /content/dataset/train/770882_mask.png
#   inflating: /content/dataset/train/770882_sat.jpg
#   inflating: /content/dataset/train/771036_mask.png
#   inflating: /content/dataset/train/771036_sat.jpg
#   inflating: /content/dataset/train/771180_mask.png
#   inflating: /content/dataset/train/771180_sat.jpg
#   inflating: /content/dataset/train/771314_mask.png
#   inflating: /content/dataset/train/771314_sat.jpg
#   inflating: /content/dataset/train/771348_mask.png
#   inflating: /content/dataset/train/771348_sat.jpg
#   inflating: /content/dataset/train/771440_mask.png
#   inflating: /content/dataset/train/771440_sat.jpg
#   inflating: /content/dataset/train/771451_mask.png
#   inflating: /content/dataset/train/771451_sat.jpg
#   inflating: /content/dataset/train/771504_mask.png
#   inflating: /content/dataset/train/771504_sat.jpg
#   inflating: /content/dataset/train/771517_mask.png
#   inflating: /content/dataset/train/771517_sat.jpg
#   inflating: /content/dataset/train/771601_mask.png
#   inflating: /content/dataset/train/771601_sat.jpg
#   inflating: /content/dataset/train/771718_mask.png
#   inflating: /content/dataset/train/771718_sat.jpg
#   inflating: /content/dataset/train/771767_mask.png
#   inflating: /content/dataset/train/771767_sat.jpg
#   inflating: /content/dataset/train/771823_mask.png
#   inflating: /content/dataset/train/771823_sat.jpg
#   inflating: /content/dataset/train/77200_mask.png
#   inflating: /content/dataset/train/77200_sat.jpg
#   inflating: /content/dataset/train/772077_mask.png
#   inflating: /content/dataset/train/772077_sat.jpg
#   inflating: /content/dataset/train/772275_mask.png
#   inflating: /content/dataset/train/772275_sat.jpg
#   inflating: /content/dataset/train/772377_mask.png
#   inflating: /content/dataset/train/772377_sat.jpg
#   inflating: /content/dataset/train/773391_mask.png
#   inflating: /content/dataset/train/773391_sat.jpg
#   inflating: /content/dataset/train/773427_mask.png
#   inflating: /content/dataset/train/773427_sat.jpg
#   inflating: /content/dataset/train/773440_mask.png
#   inflating: /content/dataset/train/773440_sat.jpg
#   inflating: /content/dataset/train/77378_mask.png
#   inflating: /content/dataset/train/77378_sat.jpg
#   inflating: /content/dataset/train/774382_mask.png
#   inflating: /content/dataset/train/774382_sat.jpg
#   inflating: /content/dataset/train/774511_mask.png
#   inflating: /content/dataset/train/774511_sat.jpg
#   inflating: /content/dataset/train/774528_mask.png
#   inflating: /content/dataset/train/774528_sat.jpg
#   inflating: /content/dataset/train/774720_mask.png
#   inflating: /content/dataset/train/774720_sat.jpg
#   inflating: /content/dataset/train/774730_mask.png
#   inflating: /content/dataset/train/774730_sat.jpg
#   inflating: /content/dataset/train/775397_mask.png
#   inflating: /content/dataset/train/775397_sat.jpg
#   inflating: /content/dataset/train/775478_mask.png
#   inflating: /content/dataset/train/775478_sat.jpg
#   inflating: /content/dataset/train/775515_mask.png
#   inflating: /content/dataset/train/775515_sat.jpg
#   inflating: /content/dataset/train/775617_mask.png
#   inflating: /content/dataset/train/775617_sat.jpg
#   inflating: /content/dataset/train/775963_mask.png
#   inflating: /content/dataset/train/775963_sat.jpg
#   inflating: /content/dataset/train/776146_mask.png
#   inflating: /content/dataset/train/776146_sat.jpg
#   inflating: /content/dataset/train/776201_mask.png
#   inflating: /content/dataset/train/776201_sat.jpg
#   inflating: /content/dataset/train/776336_mask.png
#   inflating: /content/dataset/train/776336_sat.jpg
#   inflating: /content/dataset/train/776369_mask.png
#   inflating: /content/dataset/train/776369_sat.jpg
#   inflating: /content/dataset/train/776759_mask.png
#   inflating: /content/dataset/train/776759_sat.jpg
#   inflating: /content/dataset/train/776780_mask.png
#   inflating: /content/dataset/train/776780_sat.jpg
#   inflating: /content/dataset/train/776801_mask.png
#   inflating: /content/dataset/train/776801_sat.jpg
#   inflating: /content/dataset/train/776852_mask.png
#   inflating: /content/dataset/train/776852_sat.jpg
#   inflating: /content/dataset/train/776873_mask.png
#   inflating: /content/dataset/train/776873_sat.jpg
#   inflating: /content/dataset/train/77698_mask.png
#   inflating: /content/dataset/train/77698_sat.jpg
#   inflating: /content/dataset/train/777018_mask.png
#   inflating: /content/dataset/train/777018_sat.jpg
#   inflating: /content/dataset/train/777914_mask.png
#   inflating: /content/dataset/train/777914_sat.jpg
#   inflating: /content/dataset/train/777977_mask.png
#   inflating: /content/dataset/train/777977_sat.jpg
#   inflating: /content/dataset/train/778025_mask.png
#   inflating: /content/dataset/train/778025_sat.jpg
#   inflating: /content/dataset/train/778053_mask.png
#   inflating: /content/dataset/train/778053_sat.jpg
#   inflating: /content/dataset/train/778115_mask.png
#   inflating: /content/dataset/train/778115_sat.jpg
#   inflating: /content/dataset/train/778294_mask.png
#   inflating: /content/dataset/train/778294_sat.jpg
#   inflating: /content/dataset/train/778675_mask.png
#   inflating: /content/dataset/train/778675_sat.jpg
#   inflating: /content/dataset/train/778803_mask.png
#   inflating: /content/dataset/train/778803_sat.jpg
#   inflating: /content/dataset/train/77880_mask.png
#   inflating: /content/dataset/train/77880_sat.jpg
#   inflating: /content/dataset/train/779128_mask.png
#   inflating: /content/dataset/train/779128_sat.jpg
#   inflating: /content/dataset/train/779168_mask.png
#   inflating: /content/dataset/train/779168_sat.jpg
#   inflating: /content/dataset/train/779169_mask.png
#   inflating: /content/dataset/train/779169_sat.jpg
#   inflating: /content/dataset/train/779400_mask.png
#   inflating: /content/dataset/train/779400_sat.jpg
#   inflating: /content/dataset/train/77950_mask.png
#   inflating: /content/dataset/train/77950_sat.jpg
#   inflating: /content/dataset/train/77955_mask.png
#   inflating: /content/dataset/train/77955_sat.jpg
#   inflating: /content/dataset/train/779588_mask.png
#   inflating: /content/dataset/train/779588_sat.jpg
#   inflating: /content/dataset/train/779760_mask.png
#   inflating: /content/dataset/train/779760_sat.jpg
#   inflating: /content/dataset/train/779811_mask.png
#   inflating: /content/dataset/train/779811_sat.jpg
#   inflating: /content/dataset/train/779878_mask.png
#   inflating: /content/dataset/train/779878_sat.jpg
#   inflating: /content/dataset/train/780044_mask.png
#   inflating: /content/dataset/train/780044_sat.jpg
#   inflating: /content/dataset/train/780219_mask.png
#   inflating: /content/dataset/train/780219_sat.jpg
#   inflating: /content/dataset/train/780337_mask.png
#   inflating: /content/dataset/train/780337_sat.jpg
#   inflating: /content/dataset/train/780479_mask.png
#   inflating: /content/dataset/train/780479_sat.jpg
#   inflating: /content/dataset/train/780544_mask.png
#   inflating: /content/dataset/train/780544_sat.jpg
#   inflating: /content/dataset/train/780630_mask.png
#   inflating: /content/dataset/train/780630_sat.jpg
#   inflating: /content/dataset/train/781622_mask.png
#   inflating: /content/dataset/train/781622_sat.jpg
#   inflating: /content/dataset/train/7817_mask.png
#   inflating: /content/dataset/train/7817_sat.jpg
#   inflating: /content/dataset/train/781848_mask.png
#   inflating: /content/dataset/train/781848_sat.jpg
#   inflating: /content/dataset/train/78186_mask.png
#   inflating: /content/dataset/train/78186_sat.jpg
#   inflating: /content/dataset/train/781938_mask.png
#   inflating: /content/dataset/train/781938_sat.jpg
#   inflating: /content/dataset/train/782055_mask.png
#   inflating: /content/dataset/train/782055_sat.jpg
#   inflating: /content/dataset/train/782227_mask.png
#   inflating: /content/dataset/train/782227_sat.jpg
#   inflating: /content/dataset/train/782279_mask.png
#   inflating: /content/dataset/train/782279_sat.jpg
#   inflating: /content/dataset/train/782351_mask.png
#   inflating: /content/dataset/train/782351_sat.jpg
#   inflating: /content/dataset/train/782622_mask.png
#   inflating: /content/dataset/train/782622_sat.jpg
#   inflating: /content/dataset/train/782731_mask.png
#   inflating: /content/dataset/train/782731_sat.jpg
#   inflating: /content/dataset/train/782793_mask.png
#   inflating: /content/dataset/train/782793_sat.jpg
#   inflating: /content/dataset/train/782938_mask.png
#   inflating: /content/dataset/train/782938_sat.jpg
#   inflating: /content/dataset/train/783142_mask.png
#   inflating: /content/dataset/train/783142_sat.jpg
#   inflating: /content/dataset/train/783144_mask.png
#   inflating: /content/dataset/train/783144_sat.jpg
#   inflating: /content/dataset/train/783598_mask.png
#   inflating: /content/dataset/train/783598_sat.jpg
#   inflating: /content/dataset/train/783818_mask.png
#   inflating: /content/dataset/train/783818_sat.jpg
#   inflating: /content/dataset/train/78391_mask.png
#   inflating: /content/dataset/train/78391_sat.jpg
#   inflating: /content/dataset/train/783991_mask.png
#   inflating: /content/dataset/train/783991_sat.jpg
#   inflating: /content/dataset/train/784134_mask.png
#   inflating: /content/dataset/train/784134_sat.jpg
#   inflating: /content/dataset/train/784397_mask.png
#   inflating: /content/dataset/train/784397_sat.jpg
#   inflating: /content/dataset/train/784659_mask.png
#   inflating: /content/dataset/train/784659_sat.jpg
#   inflating: /content/dataset/train/784925_mask.png
#   inflating: /content/dataset/train/784925_sat.jpg
#   inflating: /content/dataset/train/785117_mask.png
#   inflating: /content/dataset/train/785117_sat.jpg
#   inflating: /content/dataset/train/785180_mask.png
#   inflating: /content/dataset/train/785180_sat.jpg
#   inflating: /content/dataset/train/785363_mask.png
#   inflating: /content/dataset/train/785363_sat.jpg
#   inflating: /content/dataset/train/785528_mask.png
#   inflating: /content/dataset/train/785528_sat.jpg
#   inflating: /content/dataset/train/785735_mask.png
#   inflating: /content/dataset/train/785735_sat.jpg
#   inflating: /content/dataset/train/785843_mask.png
#   inflating: /content/dataset/train/785843_sat.jpg
#   inflating: /content/dataset/train/785870_mask.png
#   inflating: /content/dataset/train/785870_sat.jpg
#   inflating: /content/dataset/train/786084_mask.png
#   inflating: /content/dataset/train/786084_sat.jpg
#   inflating: /content/dataset/train/786248_mask.png
#   inflating: /content/dataset/train/786248_sat.jpg
#   inflating: /content/dataset/train/786302_mask.png
#   inflating: /content/dataset/train/786302_sat.jpg
#   inflating: /content/dataset/train/786615_mask.png
#   inflating: /content/dataset/train/786615_sat.jpg
#   inflating: /content/dataset/train/786664_mask.png
#   inflating: /content/dataset/train/786664_sat.jpg
#   inflating: /content/dataset/train/786824_mask.png
#   inflating: /content/dataset/train/786824_sat.jpg
#   inflating: /content/dataset/train/786907_mask.png
#   inflating: /content/dataset/train/786907_sat.jpg
#   inflating: /content/dataset/train/786966_mask.png
#   inflating: /content/dataset/train/786966_sat.jpg
#   inflating: /content/dataset/train/787091_mask.png
#   inflating: /content/dataset/train/787091_sat.jpg
#   inflating: /content/dataset/train/787095_mask.png
#   inflating: /content/dataset/train/787095_sat.jpg
#   inflating: /content/dataset/train/787116_mask.png
#   inflating: /content/dataset/train/787116_sat.jpg
#   inflating: /content/dataset/train/787694_mask.png
#   inflating: /content/dataset/train/787694_sat.jpg
#   inflating: /content/dataset/train/78795_mask.png
#   inflating: /content/dataset/train/78795_sat.jpg
# ...
#   inflating: /content/dataset/valid/779661_sat.jpg
#   inflating: /content/dataset/valid/78056_sat.jpg
#   inflating: /content/dataset/valid/782941_sat.jpg
#   inflating: /content/dataset/valid/783523_sat.jpg
#   inflating: /content/dataset/valid/784034_sat.jpg
#   inflating: /content/dataset/valid/784955_sat.jpg
#   inflating: /content/dataset/valid/786192_sat.jpg
#   inflating: /content/dataset/valid/786657_sat.jpg
#   inflating: /content/dataset/valid/786895_sat.jpg
#   inflating: /content/dataset/valid/787183_sat.jpg
#   inflating: /content/dataset/valid/7891_sat.jpg
#   inflating: /content/dataset/valid/791324_sat.jpg
#   inflating: /content/dataset/valid/791459_sat.jpg
#   inflating: /content/dataset/valid/791671_sat.jpg
#   inflating: /content/dataset/valid/793298_sat.jpg
#   inflating: /content/dataset/valid/793997_sat.jpg
#   inflating: /content/dataset/valid/794133_sat.jpg
#   inflating: /content/dataset/valid/795529_sat.jpg
#   inflating: /content/dataset/valid/796857_sat.jpg
#   inflating: /content/dataset/valid/797990_sat.jpg
#   inflating: /content/dataset/valid/798852_sat.jpg
#   inflating: /content/dataset/valid/799398_sat.jpg
#   inflating: /content/dataset/valid/801349_sat.jpg
#   inflating: /content/dataset/valid/802623_sat.jpg
#   inflating: /content/dataset/valid/803240_sat.jpg
#   inflating: /content/dataset/valid/803346_sat.jpg
#   inflating: /content/dataset/valid/803369_sat.jpg
#   inflating: /content/dataset/valid/803482_sat.jpg
#   inflating: /content/dataset/valid/803789_sat.jpg
#   inflating: /content/dataset/valid/804364_sat.jpg
#   inflating: /content/dataset/valid/804595_sat.jpg
#   inflating: /content/dataset/valid/805343_sat.jpg
#   inflating: /content/dataset/valid/806019_sat.jpg
#   inflating: /content/dataset/valid/80602_sat.jpg
#   inflating: /content/dataset/valid/808952_sat.jpg
#   inflating: /content/dataset/valid/810654_sat.jpg
#   inflating: /content/dataset/valid/810709_sat.jpg
#   inflating: /content/dataset/valid/811655_sat.jpg
#   inflating: /content/dataset/valid/811727_sat.jpg
#   inflating: /content/dataset/valid/811735_sat.jpg
#   inflating: /content/dataset/valid/811989_sat.jpg
#   inflating: /content/dataset/valid/812363_sat.jpg
#   inflating: /content/dataset/valid/812895_sat.jpg
#   inflating: /content/dataset/valid/812944_sat.jpg
#   inflating: /content/dataset/valid/81302_sat.jpg
#   inflating: /content/dataset/valid/813217_sat.jpg
#   inflating: /content/dataset/valid/813589_sat.jpg
#   inflating: /content/dataset/valid/813689_sat.jpg
#   inflating: /content/dataset/valid/81444_sat.jpg
#   inflating: /content/dataset/valid/814904_sat.jpg
#   inflating: /content/dataset/valid/815073_sat.jpg
#   inflating: /content/dataset/valid/815609_sat.jpg
#   inflating: /content/dataset/valid/815843_sat.jpg
#   inflating: /content/dataset/valid/816042_sat.jpg
#   inflating: /content/dataset/valid/817084_sat.jpg
#   inflating: /content/dataset/valid/817337_sat.jpg
#   inflating: /content/dataset/valid/81739_sat.jpg
#   inflating: /content/dataset/valid/819594_sat.jpg
#   inflating: /content/dataset/valid/820444_sat.jpg
#   inflating: /content/dataset/valid/821460_sat.jpg
#   inflating: /content/dataset/valid/821564_sat.jpg
#   inflating: /content/dataset/valid/825813_sat.jpg
#   inflating: /content/dataset/valid/826068_sat.jpg
#   inflating: /content/dataset/valid/826221_sat.jpg
#   inflating: /content/dataset/valid/826409_sat.jpg
#   inflating: /content/dataset/valid/826464_sat.jpg
#   inflating: /content/dataset/valid/826679_sat.jpg
#   inflating: /content/dataset/valid/827625_sat.jpg
#   inflating: /content/dataset/valid/827990_sat.jpg
#   inflating: /content/dataset/valid/828497_sat.jpg
#   inflating: /content/dataset/valid/828788_sat.jpg
#   inflating: /content/dataset/valid/829303_sat.jpg
#   inflating: /content/dataset/valid/829910_sat.jpg
#   inflating: /content/dataset/valid/830769_sat.jpg
#   inflating: /content/dataset/valid/831013_sat.jpg
#   inflating: /content/dataset/valid/832447_sat.jpg
#   inflating: /content/dataset/valid/832801_sat.jpg
#   inflating: /content/dataset/valid/833901_sat.jpg
#   inflating: /content/dataset/valid/834969_sat.jpg
#   inflating: /content/dataset/valid/836854_sat.jpg
#   inflating: /content/dataset/valid/837327_sat.jpg
#   inflating: /content/dataset/valid/837944_sat.jpg
#   inflating: /content/dataset/valid/841171_sat.jpg
#   inflating: /content/dataset/valid/841405_sat.jpg
#   inflating: /content/dataset/valid/841898_sat.jpg
#   inflating: /content/dataset/valid/841922_sat.jpg
#   inflating: /content/dataset/valid/842668_sat.jpg
#   inflating: /content/dataset/valid/84357_sat.jpg
#   inflating: /content/dataset/valid/846315_sat.jpg
#   inflating: /content/dataset/valid/846329_sat.jpg
#   inflating: /content/dataset/valid/848390_sat.jpg
#   inflating: /content/dataset/valid/849270_sat.jpg
#   inflating: /content/dataset/valid/850169_sat.jpg
#   inflating: /content/dataset/valid/851027_sat.jpg
#   inflating: /content/dataset/valid/851527_sat.jpg
#   inflating: /content/dataset/valid/853600_sat.jpg
#   inflating: /content/dataset/valid/854624_sat.jpg
#   inflating: /content/dataset/valid/854793_sat.jpg
#   inflating: /content/dataset/valid/8549_sat.jpg
#   inflating: /content/dataset/valid/855613_sat.jpg
#   inflating: /content/dataset/valid/855731_sat.jpg
#   inflating: /content/dataset/valid/856096_sat.jpg
#   inflating: /content/dataset/valid/85689_sat.jpg
#   inflating: /content/dataset/valid/858384_sat.jpg
#   inflating: /content/dataset/valid/859897_sat.jpg
#   inflating: /content/dataset/valid/861057_sat.jpg
#   inflating: /content/dataset/valid/862456_sat.jpg
#   inflating: /content/dataset/valid/862565_sat.jpg
#   inflating: /content/dataset/valid/862678_sat.jpg
#   inflating: /content/dataset/valid/862870_sat.jpg
#   inflating: /content/dataset/valid/863951_sat.jpg
#   inflating: /content/dataset/valid/864817_sat.jpg
#   inflating: /content/dataset/valid/864837_sat.jpg
#   inflating: /content/dataset/valid/86498_sat.jpg
#   inflating: /content/dataset/valid/868508_sat.jpg
#   inflating: /content/dataset/valid/868724_sat.jpg
#   inflating: /content/dataset/valid/869988_sat.jpg
#   inflating: /content/dataset/valid/870027_sat.jpg
#   inflating: /content/dataset/valid/87017_sat.jpg
#   inflating: /content/dataset/valid/870745_sat.jpg
#   inflating: /content/dataset/valid/871137_sat.jpg
#   inflating: /content/dataset/valid/871932_sat.jpg
#   inflating: /content/dataset/valid/872869_sat.jpg
#   inflating: /content/dataset/valid/874253_sat.jpg
#   inflating: /content/dataset/valid/874327_sat.jpg
#   inflating: /content/dataset/valid/874367_sat.jpg
#   inflating: /content/dataset/valid/874979_sat.jpg
#   inflating: /content/dataset/valid/875232_sat.jpg
#   inflating: /content/dataset/valid/876581_sat.jpg
#   inflating: /content/dataset/valid/87671_sat.jpg
#   inflating: /content/dataset/valid/877597_sat.jpg
#   inflating: /content/dataset/valid/877801_sat.jpg
#   inflating: /content/dataset/valid/878083_sat.jpg
#   inflating: /content/dataset/valid/879361_sat.jpg
#   inflating: /content/dataset/valid/879440_sat.jpg
#   inflating: /content/dataset/valid/879486_sat.jpg
#   inflating: /content/dataset/valid/883480_sat.jpg
#   inflating: /content/dataset/valid/883877_sat.jpg
#   inflating: /content/dataset/valid/884119_sat.jpg
#   inflating: /content/dataset/valid/884133_sat.jpg
#   inflating: /content/dataset/valid/885682_sat.jpg
#   inflating: /content/dataset/valid/886655_sat.jpg
#   inflating: /content/dataset/valid/886759_sat.jpg
#   inflating: /content/dataset/valid/887928_sat.jpg
#   inflating: /content/dataset/valid/889460_sat.jpg
#   inflating: /content/dataset/valid/889862_sat.jpg
#   inflating: /content/dataset/valid/890414_sat.jpg
#   inflating: /content/dataset/valid/89048_sat.jpg
#   inflating: /content/dataset/valid/89334_sat.jpg
#   inflating: /content/dataset/valid/893608_sat.jpg
#   inflating: /content/dataset/valid/893750_sat.jpg
#   inflating: /content/dataset/valid/895501_sat.jpg
#   inflating: /content/dataset/valid/898880_sat.jpg
#   inflating: /content/dataset/valid/900508_sat.jpg
#   inflating: /content/dataset/valid/901214_sat.jpg
#   inflating: /content/dataset/valid/901232_sat.jpg
#   inflating: /content/dataset/valid/901377_sat.jpg
#   inflating: /content/dataset/valid/901927_sat.jpg
#   inflating: /content/dataset/valid/902355_sat.jpg
#   inflating: /content/dataset/valid/904602_sat.jpg
#   inflating: /content/dataset/valid/906341_sat.jpg
#   inflating: /content/dataset/valid/906809_sat.jpg
#   inflating: /content/dataset/valid/90720_sat.jpg
#   inflating: /content/dataset/valid/907646_sat.jpg
#   inflating: /content/dataset/valid/908717_sat.jpg
#   inflating: /content/dataset/valid/908820_sat.jpg
#   inflating: /content/dataset/valid/909221_sat.jpg
#   inflating: /content/dataset/valid/909509_sat.jpg
#   inflating: /content/dataset/valid/910547_sat.jpg
#   inflating: /content/dataset/valid/910886_sat.jpg
#   inflating: /content/dataset/valid/912053_sat.jpg
#   inflating: /content/dataset/valid/912155_sat.jpg
#   inflating: /content/dataset/valid/912429_sat.jpg
#   inflating: /content/dataset/valid/912598_sat.jpg
#   inflating: /content/dataset/valid/912667_sat.jpg
#   inflating: /content/dataset/valid/913313_sat.jpg
#   inflating: /content/dataset/valid/913360_sat.jpg
#   inflating: /content/dataset/valid/913377_sat.jpg
#   inflating: /content/dataset/valid/913700_sat.jpg
#   inflating: /content/dataset/valid/914093_sat.jpg
#   inflating: /content/dataset/valid/914177_sat.jpg
#   inflating: /content/dataset/valid/91547_sat.jpg
#   inflating: /content/dataset/valid/915769_sat.jpg
#   inflating: /content/dataset/valid/91576_sat.jpg
#   inflating: /content/dataset/valid/916264_sat.jpg
#   inflating: /content/dataset/valid/91705_sat.jpg
#   inflating: /content/dataset/valid/917195_sat.jpg
#   inflating: /content/dataset/valid/918160_sat.jpg
#   inflating: /content/dataset/valid/918431_sat.jpg
#   inflating: /content/dataset/valid/918710_sat.jpg
#   inflating: /content/dataset/valid/919706_sat.jpg
#   inflating: /content/dataset/valid/919821_sat.jpg
#   inflating: /content/dataset/valid/920117_sat.jpg
#   inflating: /content/dataset/valid/920159_sat.jpg
#   inflating: /content/dataset/valid/924388_sat.jpg
#   inflating: /content/dataset/valid/924448_sat.jpg
#   inflating: /content/dataset/valid/925040_sat.jpg
#   inflating: /content/dataset/valid/925158_sat.jpg
#   inflating: /content/dataset/valid/928159_sat.jpg
#   inflating: /content/dataset/valid/92857_sat.jpg
#   inflating: /content/dataset/valid/929207_sat.jpg
#   inflating: /content/dataset/valid/929712_sat.jpg
#   inflating: /content/dataset/valid/931181_sat.jpg
#   inflating: /content/dataset/valid/931936_sat.jpg
#   inflating: /content/dataset/valid/933350_sat.jpg
#   inflating: /content/dataset/valid/934163_sat.jpg
#   inflating: /content/dataset/valid/934566_sat.jpg
#   inflating: /content/dataset/valid/934630_sat.jpg
#   inflating: /content/dataset/valid/934702_sat.jpg
#   inflating: /content/dataset/valid/934966_sat.jpg
#   inflating: /content/dataset/valid/935735_sat.jpg
#   inflating: /content/dataset/valid/936595_sat.jpg
#   inflating: /content/dataset/valid/936728_sat.jpg
#   inflating: /content/dataset/valid/9397_sat.jpg
#   inflating: /content/dataset/valid/940200_sat.jpg
#   inflating: /content/dataset/valid/941752_sat.jpg
#   inflating: /content/dataset/valid/94180_sat.jpg
#   inflating: /content/dataset/valid/94244_sat.jpg
#   inflating: /content/dataset/valid/943481_sat.jpg
#   inflating: /content/dataset/valid/943789_sat.jpg
#   inflating: /content/dataset/valid/944089_sat.jpg
#   inflating: /content/dataset/valid/945308_sat.jpg
#   inflating: /content/dataset/valid/945487_sat.jpg
#   inflating: /content/dataset/valid/946257_sat.jpg
#   inflating: /content/dataset/valid/947617_sat.jpg
#   inflating: /content/dataset/valid/948195_sat.jpg
#   inflating: /content/dataset/valid/950001_sat.jpg
#   inflating: /content/dataset/valid/950093_sat.jpg
#   inflating: /content/dataset/valid/950375_sat.jpg
#   inflating: /content/dataset/valid/953107_sat.jpg
#   inflating: /content/dataset/valid/953331_sat.jpg
#   inflating: /content/dataset/valid/954006_sat.jpg
#   inflating: /content/dataset/valid/954888_sat.jpg
#   inflating: /content/dataset/valid/955601_sat.jpg
#   inflating: /content/dataset/valid/956552_sat.jpg
#   inflating: /content/dataset/valid/957501_sat.jpg
#   inflating: /content/dataset/valid/957602_sat.jpg
#   inflating: /content/dataset/valid/958238_sat.jpg
#   inflating: /content/dataset/valid/958239_sat.jpg
#   inflating: /content/dataset/valid/958946_sat.jpg
#   inflating: /content/dataset/valid/959677_sat.jpg
#   inflating: /content/dataset/valid/961129_sat.jpg
#   inflating: /content/dataset/valid/963385_sat.jpg
#   inflating: /content/dataset/valid/964271_sat.jpg
#   inflating: /content/dataset/valid/964987_sat.jpg
#   inflating: /content/dataset/valid/965066_sat.jpg
#   inflating: /content/dataset/valid/967432_sat.jpg
#   inflating: /content/dataset/valid/967824_sat.jpg
#   inflating: /content/dataset/valid/968415_sat.jpg
#   inflating: /content/dataset/valid/970007_sat.jpg
#   inflating: /content/dataset/valid/971893_sat.jpg
#   inflating: /content/dataset/valid/972010_sat.jpg
#   inflating: /content/dataset/valid/972123_sat.jpg
#   inflating: /content/dataset/valid/974127_sat.jpg
#   inflating: /content/dataset/valid/97434_sat.jpg
#   inflating: /content/dataset/valid/974785_sat.jpg
#   inflating: /content/dataset/valid/974960_sat.jpg
#   inflating: /content/dataset/valid/97598_sat.jpg
#   inflating: /content/dataset/valid/976443_sat.jpg
#   inflating: /content/dataset/valid/979591_sat.jpg
#   inflating: /content/dataset/valid/979651_sat.jpg
#   inflating: /content/dataset/valid/979824_sat.jpg
#   inflating: /content/dataset/valid/981739_sat.jpg
#   inflating: /content/dataset/valid/981785_sat.jpg
#   inflating: /content/dataset/valid/9821_sat.jpg
#   inflating: /content/dataset/valid/982728_sat.jpg
#   inflating: /content/dataset/valid/983142_sat.jpg
#   inflating: /content/dataset/valid/983867_sat.jpg
#   inflating: /content/dataset/valid/983896_sat.jpg
#   inflating: /content/dataset/valid/983911_sat.jpg
#   inflating: /content/dataset/valid/984577_sat.jpg
#   inflating: /content/dataset/valid/984706_sat.jpg
#   inflating: /content/dataset/valid/985641_sat.jpg
#   inflating: /content/dataset/valid/985869_sat.jpg
#   inflating: /content/dataset/valid/986231_sat.jpg
#   inflating: /content/dataset/valid/986696_sat.jpg
#   inflating: /content/dataset/valid/988215_sat.jpg
#   inflating: /content/dataset/valid/98828_sat.jpg
#   inflating: /content/dataset/valid/988686_sat.jpg
#   inflating: /content/dataset/valid/9893_sat.jpg
#   inflating: /content/dataset/valid/990104_sat.jpg
#   inflating: /content/dataset/valid/99032_sat.jpg
#   inflating: /content/dataset/valid/990888_sat.jpg
#   inflating: /content/dataset/valid/991366_sat.jpg
#   inflating: /content/dataset/valid/991606_sat.jpg
#   inflating: /content/dataset/valid/991978_sat.jpg
#   inflating: /content/dataset/valid/992520_sat.jpg
#   inflating: /content/dataset/valid/993282_sat.jpg
#   inflating: /content/dataset/valid/993402_sat.jpg
#   inflating: /content/dataset/valid/993408_sat.jpg
#   inflating: /content/dataset/valid/993415_sat.jpg
#   inflating: /content/dataset/valid/994006_sat.jpg
#   inflating: /content/dataset/valid/994111_sat.jpg
#   inflating: /content/dataset/valid/994141_sat.jpg
#   inflating: /content/dataset/valid/994375_sat.jpg
#   inflating: /content/dataset/valid/994998_sat.jpg
#   inflating: /content/dataset/valid/995317_sat.jpg
#   inflating: /content/dataset/valid/995370_sat.jpg
#   inflating: /content/dataset/valid/995930_sat.jpg
#   inflating: /content/dataset/valid/997473_sat.jpg
#   inflating: /content/dataset/valid/998148_sat.jpg
#   inflating: /content/dataset/valid/999753_sat.jpg

# %%
# !pip install tensorflow keras opencv-python timm albumentations matplotlib scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Collecting timm
#   Downloading timm-1.0.9-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.4.14)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.4.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.19.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.24.6)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.23.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (2.8.2)
# Requirement already satisfied: albucore>=0.0.13 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.14)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.2.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (3.3)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (2024.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations) (0.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2024.6.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.66.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm) (1.3.0)
# Downloading timm-1.0.9-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.4 MB/s eta 0:00:00
# Installing collected packages: timm
# Successfully installed timm-1.0.9

# %%
from tensorflow.keras.utils import Sequence
import cv2
import numpy as np
import os
from sklearn.model_selection import train_test_split

# Data Generator برای لود کردن تصاویر و ماسک‌ها به صورت batch
class DataGenerator(Sequence):
    def __init__(self, image_filenames, mask_filenames=None, image_dir='', mask_dir='', batch_size=8, image_size=(256, 256), shuffle=True):
        self.image_filenames = image_filenames
        self.mask_filenames = mask_filenames
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.image_filenames) / self.batch_size))

    def __getitem__(self, index):
        # تولید یک batch از داده‌ها
        batch_image_filenames = self.image_filenames[index * self.batch_size:(index + 1) * self.batch_size]


        images = []
        masks = []

        for file_name in batch_image_filenames:
            img_path = os.path.join(self.image_dir, file_name)
            image = cv2.imread(img_path)
            image = cv2.resize(image, self.image_size)
            images.append(image)

            if self.mask_filenames is not None:
                mask_name = file_name.replace('_sat.jpg', '_mask.png')
                mask_path = os.path.join(self.mask_dir, mask_name)
                mask = cv2.imread(mask_path, 0)
                mask = cv2.resize(mask, self.image_size)

                # تبدیل ماسک به باینری (مقادیر 0 و 1)
                mask = (mask > 128).astype(np.uint8)  # هر پیکسل بزرگتر از 128 را 1 و بقیه را 0 می‌کند.

                mask = np.expand_dims(mask, axis=-1)
                masks.append(mask)

        images = np.array(images)
        if self.mask_filenames is not None:
            masks = np.array(masks)
            return images, masks
        else:
            return images

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.image_filenames))
            np.random.shuffle(indices)
            self.image_filenames = [self.image_filenames[i] for i in indices]
            if self.mask_filenames is not None:
                self.mask_filenames = [self.mask_filenames[i] for i in indices]

# تقسیم داده‌ها به train و validation
train_image_dir = '/content/dataset/train'
train_mask_dir = '/content/dataset/train'

# لیست فایل‌های تصویر و ماسک‌ها را لود می‌کنیم
image_filenames = sorted([f for f in os.listdir(train_image_dir) if f.endswith('_sat.jpg')])
mask_filenames = sorted([f for f in os.listdir(train_mask_dir) if f.endswith('_mask.png')])

# تقسیم داده‌ها به 80% train و 20% validation
train_image_filenames, valid_image_filenames, train_mask_filenames, valid_mask_filenames = train_test_split(
    image_filenames, mask_filenames, test_size=0.2, random_state=42)

# ساخت DataGenerator برای train
train_generator = DataGenerator(image_filenames=train_image_filenames, mask_filenames=train_mask_filenames,
                                image_dir=train_image_dir, mask_dir=train_mask_dir, batch_size=8, image_size=(256, 256))

# ساخت DataGenerator برای validation
valid_generator = DataGenerator(image_filenames=valid_image_filenames, mask_filenames=valid_mask_filenames,
                                image_dir=train_image_dir, mask_dir=train_mask_dir, batch_size=8, image_size=(256, 256), shuffle=False)

# تست روی فایل‌های test
test_image_dir = '/content/dataset/test'
test_image_filenames = sorted([f for f in os.listdir(test_image_dir) if f.endswith('_sat.jpg')])

# ساخت DataGenerator برای test (بدون ماسک)
test_generator = DataGenerator(image_filenames=test_image_filenames, image_dir=test_image_dir, batch_size=8, image_size=(256, 256), shuffle=False)

# %%
import matplotlib.pyplot as plt
import cv2

# دریافت یک batch از تصاویر و ماسک‌ها
images, masks = train_generator[0]

# تبدیل تصاویر از BGR به RGB
images_rgb = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in images]

# نمایش یک تصویر و ماسک مربوطه
plt.subplot(1, 2, 1)
plt.imshow(images_rgb[0])
plt.title('Image (RGB)')

plt.subplot(1, 2, 2)
plt.imshow(masks[0].squeeze(), cmap='gray')
plt.title('Binary Mask')

plt.show()

# %%
print(f"Training samples: {len(train_generator)}, Validation samples: {len(valid_generator)}")
# Out:
# Training samples: 622, Validation samples: 155

# %%
# from tensorflow.keras.utils import Sequence
# import cv2
# import numpy as np
# import os

# # Data Generator برای لود کردن تصاویر و ماسک‌ها به صورت batch
# class DataGenerator(Sequence):
#     def __init__(self, image_dir, mask_dir=None, batch_size=8, image_size=(256, 256), shuffle=True):
#         super().__init__()
#         self.image_dir = image_dir
#         self.mask_dir = mask_dir
#         self.batch_size = batch_size
#         self.image_size = image_size
#         self.shuffle = shuffle
#         self.image_filenames = sorted([f for f in os.listdir(image_dir) if f.endswith('_sat.jpg')])
#         if mask_dir:
#             self.mask_filenames = sorted([f for f in os.listdir(mask_dir) if f.endswith('_mask.png')])
#         self.on_epoch_end()

#     def __len__(self):
#         # تعداد batch‌ها در هر epoch
#         return int(np.floor(len(self.image_filenames) / self.batch_size))

#     def __getitem__(self, index):
#         # تولید یک batch از داده‌ها
#         batch_image_filenames = self.image_filenames[index * self.batch_size:(index + 1) * self.batch_size]

#         images = []
#         masks = []

#         for file_name in batch_image_filenames:
#             img_path = os.path.join(self.image_dir, file_name)
#             image = cv2.imread(img_path)
#             image = cv2.resize(image, self.image_size)
#             images.append(image)

#             if self.mask_dir:
#                 mask_name = file_name.replace('_sat.jpg', '_mask.png')
#                 mask_path = os.path.join(self.mask_dir, mask_name)
#                 mask = cv2.imread(mask_path, 0)
#                 mask = cv2.resize(mask, self.image_size)
#                 mask = np.expand_dims(mask, axis=-1)
#                 mask = mask /255.0
#                 masks.append(mask)

#         images = np.array(images)
#         if self.mask_dir:
#             masks = np.array(masks)
#             return images, masks
#         else:
#             return images

#     def on_epoch_end(self):
#         if self.shuffle:
#             np.random.shuffle(self.image_filenames)

# # استفاده از DataGenerator برای لود کردن داده‌ها
# train_image_dir = '/content/drive/MyDrive/train'
# train_mask_dir = '/content/drive/MyDrive/train'

# valid_image_dir = '/content/drive/MyDrive/valid'
# test_image_dir = '/content/drive/MyDrive/test'

# # ساخت DataGenerator برای train
# train_generator = DataGenerator(image_dir=train_image_dir, mask_dir=train_mask_dir, batch_size=4, image_size=(256, 256))

# # ساخت DataGenerator برای validation و test فقط با تصاویر
# valid_generator = DataGenerator(image_dir=valid_image_dir, batch_size=4, image_size=(256, 256), shuffle=False)
# test_generator = DataGenerator(image_dir=test_image_dir, batch_size=4, image_size=(256, 256), shuffle=False)

# %%
# # دریافت یک batch از داده‌های train
# images, masks = next(iter(train_generator))

# # پیش‌بینی با مدل
# predictions = model.predict(images)

# # چاپ شکل (dimensions) خروجی‌ها
# print(f"Shape of images: {images.shape}")
# print(f"Shape of masks: {masks.shape}")
# print(f"Shape of predictions: {predictions.shape}")

# %%
print(f"Training samples: {len(train_generator)}, Validation samples: {len(valid_generator)}")
# Out:
# Training samples: 622, Validation samples: 155

# %%
import tensorflow as tf

# یک لایه سفارشی برای انجام Patch Embedding
class PatchEmbeddingLayer(tf.keras.layers.Layer):
    def __init__(self, patch_size=4, embed_dim=48, **kwargs):
        super(PatchEmbeddingLayer, self).__init__(**kwargs)
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.dense = tf.keras.layers.Dense(embed_dim)

    def call(self, images):
        # تبدیل تصویر به پچ‌های کوچک
        patches = tf.image.extract_patches(images=images,
                                           sizes=[1, self.patch_size, self.patch_size, 1],
                                           strides=[1, self.patch_size, self.patch_size, 1],
                                           rates=[1, 1, 1, 1],
                                           padding='VALID')
        patches = tf.reshape(patches, [tf.shape(patches)[0], -1, self.patch_size * self.patch_size * 3])
        return self.dense(patches)

# یک بلوک از Swin Transformer شامل Self Attention و MLP
class SwinTransformerBlock(tf.keras.layers.Layer):
    def __init__(self, dim, num_heads, window_size, mlp_ratio=4., **kwargs):
        super(SwinTransformerBlock, self).__init__(**kwargs)
        self.dim = dim
        self.num_heads = num_heads
        self.window_size = window_size
        self.mlp_ratio = mlp_ratio
        self.norm1 = tf.keras.layers.LayerNormalization(epsilon=1e-5)
        self.attn = tf.keras.layers.MultiHeadAttention(num_heads=2, key_dim=dim // 2)
        self.norm2 = tf.keras.layers.LayerNormalization(epsilon=1e-5)
        self.mlp = tf.keras.Sequential([
            tf.keras.layers.Dense(int(dim * mlp_ratio)),
            tf.keras.layers.Activation('gelu'),
            tf.keras.layers.Dense(dim)
        ])

    def call(self, x):
        # محاسبه Self Attention
        h = x
        x = self.norm1(x)
        x = self.attn(x, x)
        x = x + h

        # محاسبه MLP
        h = x
        x = self.norm2(x)
        x = self.mlp(x)
        x = x + h
        return x

# Swin Transformer نهایی
def swin_transformer(input_shape=(256, 256, 3), patch_size=4, num_heads=2, window_size=7, embed_dim=48):
    inputs = tf.keras.Input(shape=input_shape)

    # مرحله اول: تبدیل تصویر به پچ‌ها با استفاده از لایه سفارشی
    x = PatchEmbeddingLayer(patch_size=patch_size, embed_dim=embed_dim)(inputs)

    # مرحله دوم: بلوک‌های Swin Transformer
    x = SwinTransformerBlock(dim=embed_dim, num_heads=num_heads, window_size=window_size)(x)

    # Global Pooling
    x = tf.keras.layers.GlobalAveragePooling1D()(x)

    return tf.keras.Model(inputs, x)

# ساخت مدل Swin Transformer
swin_model = swin_transformer()

# نمایش خلاصه مدل
swin_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ patch_embedding_layer                │ (None, None, 48)            │           2,352 │
# │ (PatchEmbeddingLayer)                │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ swin_transformer_block               │ (None, None, 48)            │          28,272 │
# │ (SwinTransformerBlock)               │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ (None, 48)                  │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,624 (119.62 KB)
#  Trainable params: 30,624 (119.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# from tensorflow.keras.layers import Conv2D, UpSampling2D

# # ساخت مدل نهایی با Swin Transformer و CNN
# def build_conswin_model(input_shape=(512, 512, 3)):
#     inputs = tf.keras.Input(shape=input_shape)

#     # Swin Transformer به عنوان backbone
#     swin_backbone = swin_transformer(input_shape=input_shape)  # استفاده از تابع swin_transformer
#     swin_output = swin_backbone(inputs)

#     # تبدیل خروجی Swin Transformer به ابعاد مناسب برای لایه‌های کانولوشنی
#     x = tf.keras.layers.Reshape((16, 16, -1))(swin_output)  # تنظیم دستی ابعاد (در اینجا فرض شده که ابعاد خروجی 16x16 است)

#     # لایه‌های CNN
#     x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
#     x = UpSampling2D(size=(2, 2))(x)  # بزرگ‌نمایی تصویر
#     x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
#     x = UpSampling2D(size=(2, 2))(x)  # بزرگ‌نمایی تصویر
#     x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
#     x = UpSampling2D(size=(2, 2))(x)  # بزرگ‌نمایی تصویر

#     # لایه نهایی برای تولید نقشه‌های تقسیم‌بندی (segmentation map)
#     final_output = Conv2D(1, (1, 1), activation='sigmoid')(x)

#     # ساخت مدل نهایی
#     model = tf.keras.Model(inputs=inputs, outputs=final_output)

#     # کامپایل مدل
#     model.compile(optimizer='adam',
#                   loss='binary_crossentropy',
#                   metrics=['accuracy'])

#     return model

# # ساخت مدل
# model = build_conswin_model()

# # نمایش خلاصه مدل
# model.summary()

# %%
# from tensorflow.keras.layers import Conv2D, UpSampling2D

# # ساخت مدل نهایی با Swin Transformer و CNN
# def build_conswin_model(input_shape=(256, 256, 3)):
#     inputs = tf.keras.Input(shape=input_shape)

#     # Swin Transformer به عنوان backbone
#     swin_backbone = swin_transformer(input_shape=input_shape)  # استفاده از تابع swin_transformer
#     swin_output = swin_backbone(inputs)

#     # چاپ ابعاد خروجی Swin Transformer
#     print(f"Output shape of Swin Transformer: {swin_output.shape}")

#     # ادامه پردازش CNN بعد از بررسی ابعاد
#     # برای Reshape ابتدا ابعاد صحیح خروجی Swin Transformer را چاپ می‌کنیم و سپس اصلاح می‌کنیم

#     return tf.keras.Model(inputs=inputs, outputs=swin_output)

# # ساخت مدل
# model = build_conswin_model()

# # نمایش خلاصه مدل
# model.summary()

# %%
from tensorflow.keras.layers import Conv2D, UpSampling2D, Dense, Reshape

# # ساخت مدل نهایی با Swin Transformer و CNN
# def build_conswin_model(input_shape=(256, 256, 3)):  # تغییر ابعاد ورودی به 256x256
#     inputs = tf.keras.Input(shape=input_shape)

#     # Swin Transformer به عنوان backbone
#     swin_backbone = swin_transformer(input_shape=input_shape)  # استفاده از تابع swin_transformer
#     swin_output = swin_backbone(inputs)

#     # تبدیل خروجی Swin Transformer به ابعاد مناسب
#     x = Dense(8 * 8 * 64, activation='relu')(swin_output)  # تنظیم ابعاد به 8x8x64
#     x = Reshape((8, 8, 64))(x)  # تبدیل به نقشه ویژگی 2D با ابعاد 8x8

#     # لایه‌های CNN برای بزرگ‌نمایی تصویر
#     x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
#     x = UpSampling2D(size=(2, 2))(x)  # بزرگ‌نمایی به 16x16
#     x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
#     x = UpSampling2D(size=(2, 2))(x)  # بزرگ‌نمایی به 32x32
#     x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
#     x = UpSampling2D(size=(2, 2))(x)  # بزرگ‌نمایی به 64x64
#     x = UpSampling2D(size=(4, 4))(x)  # بزرگ‌نمایی به 256x256

#     # لایه نهایی برای تولید نقشه‌های تقسیم‌بندی (segmentation map)
#     final_output = Conv2D(1, (1, 1), activation='sigmoid')(x)

#     # ساخت مدل نهایی
#     model = tf.keras.Model(inputs=inputs, outputs=final_output)

#     # کامپایل مدل
#     model.compile(optimizer='adam',
#                   loss='binary_crossentropy',
#                   metrics=['accuracy'])

#     return model
# import tensorflow.keras.backend as K

# # تعریف متریک IoU (Intersection over Union)
# def iou(y_true, y_pred):
#     intersection = K.sum(K.abs(y_true * y_pred))
#     union = K.sum(y_true) + K.sum(y_pred) - intersection
#     return intersection / (union + K.epsilon())

# # تعریف متریک F1-Score
# def f1_score(y_true, y_pred):
#     def precision(y_true, y_pred):
#         true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#         predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#         precision = true_positives / (predicted_positives + K.epsilon())
#         return precision

#     def recall(y_true, y_pred):
#         true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#         possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#         recall = true_positives / (possible_positives + K.epsilon())
#         return recall

#     precision_val = precision(y_true, y_pred)
#     recall_val = recall(y_true, y_pred)
#     return 2 * ((precision_val * recall_val) / (precision_val + recall_val + K.epsilon()))


import tensorflow.keras.backend as K

# تعریف متریک IoU (Intersection over Union)
def iou(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')  # تبدیل y_true به float32
    y_pred = K.cast(y_pred, 'float32')  # تبدیل y_pred به float32

    intersection = K.sum(K.abs(y_true * y_pred))
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    iou_val = intersection / (union + K.epsilon())
    return iou_val

# تعریف متریک F1-Score
def f1_score(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')  # تبدیل y_true به float32
    y_pred = K.cast(y_pred, 'float32')  # تبدیل y_pred به float32

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    precision_val = precision(y_true, y_pred)
    recall_val = recall(y_true, y_pred)
    f1_val = 2 * ((precision_val * recall_val) / (precision_val + recall_val + K.epsilon()))
    return f1_val

# تعریف Dice Loss و ترکیب آن با Binary Crossentropy
def dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    intersection = K.sum(y_true * y_pred)
    return 1 - (2. * intersection + K.epsilon()) / (K.sum(y_true) + K.sum(y_pred) + K.epsilon())

def bce_dice_loss(y_true, y_pred):
    bce = K.binary_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return bce + dice

from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2
# اضافه کردن لایه‌های Dropout به مدل
def build_conswin_model(input_shape=(256, 256, 3)):
    inputs = tf.keras.Input(shape=input_shape)

    # Swin Transformer as backbone
    swin_backbone = swin_transformer(input_shape=input_shape)
    swin_output = swin_backbone(inputs)

    # اگر ابعاد خروجی swin_backbone 2 بعدی است، نیاز است آن را reshape کنیم
    if len(swin_output.shape) == 2:
        swin_output = Reshape((1, 1, swin_output.shape[-1]))(swin_output)

    # استفاده از Global Average Pooling به جای Dense
    x = tf.keras.layers.GlobalAveragePooling2D()(swin_output)

    # تبدیل خروجی به نقشه ویژگی با Conv2D
    x = Reshape((1, 1, -1))(x)  # تنظیم ابعاد به 1x1 کانال‌ها
    x = Conv2D(64, (1, 1), activation='relu')(x)
    x = UpSampling2D(size=(32, 32))(x)  # بزرگ‌نمایی به 32x32

    # لایه‌های CNN و Dropout
    x = Conv2D(64, (3, 3), activation='relu', padding='same',kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)
    x = UpSampling2D(size=(2, 2))(x)

    x = Conv2D(32, (3, 3), activation='relu', padding='same',kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)
    x = UpSampling2D(size=(2, 2))(x)

    x = UpSampling2D(size=(2, 2))(x)

    # لایه نهایی
    final_output = Conv2D(1, (1, 1), activation='sigmoid')(x)

    # ساخت مدل
    model = tf.keras.Model(inputs=inputs, outputs=final_output)

    # کامپایل مدل
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=1.0)
    model.compile(optimizer=optimizer,
                  loss=dice_loss,
                  metrics=['accuracy', iou, f1_score])

    return model
# ساخت مدل
model = build_conswin_model()

# نمایش خلاصه مدل
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ functional_3 (Functional)            │ (None, 48)                  │          30,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 1, 1, 48)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 48)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_1 (Reshape)                  │ (None, 1, 1, 48)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 1, 1, 64)            │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 64, 64, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_2 (UpSampling2D)       │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_3 (UpSampling2D)       │ (None, 256, 256, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 256, 256, 1)         │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 89,185 (348.38 KB)
#  Trainable params: 89,185 (348.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# # تنظیمات Data Augmentation
# datagen = ImageDataGenerator(
#     rotation_range=20,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     fill_mode='nearest')

# %%
# from tensorflow.keras.callbacks import EarlyStopping

# # تعریف Early Stopping برای جلوگیری از بیش‌برازش
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# # تعریف class weights
# import numpy as np

# # ایجاد sample_weights براساس ماسک‌ها
# def create_sample_weights(y_true, class_weights):
#     # فرض کنید y_true یک ماسک با مقادیر 0 (پس‌زمینه) و 1 (جاده) باشد
#     sample_weights = np.ones(y_true.shape)
#     sample_weights[y_true == 0] = class_weights[0]  # وزن‌دهی به پیکسل‌های پس‌زمینه
#     sample_weights[y_true == 1] = class_weights[1]  # وزن‌دهی به پیکسل‌های جاده
#     return sample_weights

# # # ایجاد sample_weights برای داده‌های آموزشی
# # sample_weights = create_sample_weights(y_train, class_weights)

# # # آموزش مدل با sample_weights
# # history = model.fit(datagen.flow(X_train, y_train, batch_size=8),  # استفاده از Data Augmentation
# #                     validation_data=(X_val, y_val),
# #                     epochs=50,
# #                     sample_weight=sample_weights,  # استفاده از sample_weights
# #                     callbacks=[early_stopping])


# augmented_images, augmented_masks = [], []

# # ایجاد یک generator برای Data Augmentation
# data_gen = datagen.flow(X_train, y_train, batch_size=8, shuffle=False)

# # دریافت تمام داده‌های Augmented
# for _ in range(len(X_train) // 8):  # تقسیم داده‌ها به Batch‌ها
#     imgs, masks = next(data_gen)
#     augmented_images.extend(imgs)
#     augmented_masks.extend(masks)

# augmented_images = np.array(augmented_images)
# augmented_masks = np.array(augmented_masks)

# # ایجاد sample_weights براساس ماسک‌ها
# sample_weights = create_sample_weights(augmented_masks, class_weights)

# # آموزش مدل با داده‌های Augmented و sample_weights
# history = model.fit(augmented_images, augmented_masks,  # استفاده از داده‌های Augmented به صورت دستی
#                     sample_weight=sample_weights,  # اضافه کردن sample_weights
#                     validation_data=(X_val, y_val),
#                     epochs=10,
#                     callbacks=[early_stopping])



# # # آموزش مدل با استفاده از Data Augmentation
# # history = model.fit(datagen.flow(X_train, y_train, batch_size=8),  # استفاده از Data Augmentation
# #                     validation_data=(X_val, y_val),
# #                     epochs=50,
# #                     callbacks=[early_stopping])

# %%
# !pip install tensorflow keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# تنظیمات callback
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# آموزش مدل
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=10,
    callbacks=[early_stopping, reduce_lr, checkpoint]
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 200s 290ms/step - accuracy: 0.5802 - f1_score: 0.0874 - iou: 0.0461 - loss: 0.9209 - val_accuracy: 0.5191 - val_f1_score: 0.1022 - val_iou: 0.0542 - val_loss: 0.9033 - learning_rate: 1.0000e-04
# Epoch 2/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 163s 260ms/step - accuracy: 0.6088 - f1_score: 0.0999 - iou: 0.0531 - loss: 0.9050 - val_accuracy: 0.6260 - val_f1_score: 0.1030 - val_iou: 0.0547 - val_loss: 0.9020 - learning_rate: 1.0000e-04
# Epoch 3/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 174s 278ms/step - accuracy: 0.6694 - f1_score: 0.1027 - iou: 0.0548 - loss: 0.9017 - val_accuracy: 0.6490 - val_f1_score: 0.1075 - val_iou: 0.0577 - val_loss: 0.8966 - learning_rate: 1.0000e-04
# Epoch 4/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 192s 262ms/step - accuracy: 0.6833 - f1_score: 0.1076 - iou: 0.0575 - loss: 0.8966 - val_accuracy: 0.6600 - val_f1_score: 0.1072 - val_iou: 0.0576 - val_loss: 0.8965 - learning_rate: 1.0000e-04
# Epoch 5/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 163s 260ms/step - accuracy: 0.6467 - f1_score: 0.1034 - iou: 0.0552 - loss: 0.9005 - val_accuracy: 0.7954 - val_f1_score: 0.1114 - val_iou: 0.0601 - val_loss: 0.8927 - learning_rate: 1.0000e-04
# Epoch 6/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 202s 260ms/step - accuracy: 0.6924 - f1_score: 0.1063 - iou: 0.0571 - loss: 0.8974 - val_accuracy: 0.7291 - val_f1_score: 0.1108 - val_iou: 0.0597 - val_loss: 0.8926 - learning_rate: 1.0000e-04
# Epoch 7/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 161s 258ms/step - accuracy: 0.7280 - f1_score: 0.1028 - iou: 0.0551 - loss: 0.9007 - val_accuracy: 0.6714 - val_f1_score: 0.1176 - val_iou: 0.0634 - val_loss: 0.8859 - learning_rate: 1.0000e-04
# Epoch 8/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 165s 262ms/step - accuracy: 0.6914 - f1_score: 0.1081 - iou: 0.0580 - loss: 0.8953 - val_accuracy: 0.7115 - val_f1_score: 0.1096 - val_iou: 0.0593 - val_loss: 0.8929 - learning_rate: 1.0000e-04
# Epoch 9/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 211s 277ms/step - accuracy: 0.6587 - f1_score: 0.1048 - iou: 0.0561 - loss: 0.8983 - val_accuracy: 0.6965 - val_f1_score: 0.1134 - val_iou: 0.0611 - val_loss: 0.8896 - learning_rate: 1.0000e-04
# Epoch 10/10
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 164s 261ms/step - accuracy: 0.6826 - f1_score: 0.1051 - iou: 0.0562 - loss: 0.8979 - val_accuracy: 0.6689 - val_f1_score: 0.1190 - val_iou: 0.0641 - val_loss: 0.8841 - learning_rate: 1.0000e-04

# %%
import matplotlib.pyplot as plt

# تابع پیش‌بینی روی تصویر جدید
def predict_image(image, model):
    image_resized = cv2.resize(image, (256, 256))  # تغییر اندازه تصویر به 256x256
    image_resized = np.expand_dims(image_resized, axis=0)  # افزودن بعد batch
    prediction = model.predict(image_resized)
    return np.squeeze(prediction)

# مثال پیش‌بینی
sample_image = X_val[0]  # یک نمونه از داده‌های اعتبارسنجی
prediction = predict_image(sample_image, model)

# نمایش تصویر اصلی و ماسک پیش‌بینی شده
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(sample_image)

plt.subplot(1, 2, 2)
plt.title('Predicted Mask')
plt.imshow(prediction, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ca0af5dfac12> in <cell line: 11>()
#       9
#      10 # مثال پیش‌بینی
# ---> 11 sample_image = X_val[0]  # یک نمونه از داده‌های اعتبارسنجی
#      12 prediction = predict_image(sample_image, model)
#      13
#
# NameError: name 'X_val' is not defined
